# %%
#SEABORN

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips= sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Scatter plot axis level function
sns.scatterplot(data = tips, x='total_bill',y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#rel plot- figure level function-square shape
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter')

# %%
flights = sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
may_flights = flights.query("month == 'May'")
sns.lineplot(data=may_flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights_wide = flights.pivot(index="year", columns="month", values="passengers")
flights_wide.head()
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
sns.lineplot(data=flights_wide["May"])
# Out:
# <Axes: xlabel='year', ylabel='May'>

# %%
sns.lineplot(data=flights_wide)
# Out:
# <Axes: xlabel='year'>

# %%
#distribution plot

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(data=penguins, x="body_mass_g")

# %%
sns.displot(data=penguins, x="bill_depth_mm", kind="kde")

# %%
sns.displot(data=penguins, x="flipper_length_mm", kde=True)

# %%
#SEABORN

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
import pandas as pd

# %%
var = [1,2,3,4,5,6,7]
var_1 = [2,3,4,1,5,6,7]
x_1 = pd.DataFrame({"var":var,"var_1":var_1})
sns.lineplot(x="var",y="var_1",data=x_1)

plt.show()

# %%
a = sns.load_dataset("penguins")
a

# %%
sns.lineplot(x="bill_length_mm", y="flipper_length_mm",data=a,hue="sex",size=10, style="sex",palette="BuPu",markers=["o",">"])
plt.show()

# %%
sns.load_dataset("penguins").head(20)

# %%
sns.lineplot(x="bill_length_mm", y="flipper_length_mm",data=a,hue="sex",size=10, style="sex",palette="BuPu",markers=["o",">"],dashes=False,legend="full")
plt.show() 
plt.grid()
plt.title("python")

# %%
 #dis = #Histogram

# %%
sns.displot(a["flipper_length_mm"], bins=[170,180,190,200,210,220,230,240],kde=True,color="g",rug=True)
plt.show()

# %%
#Bar plot

# %%
var = sns.load_dataset("penguins")
var

# %%
sns.set(style="dark")
order_1 = ["Dream","Biscoe", "Torgersen"]
sns.barplot(x="island", y="bill_length_mm",data=var,hue="sex",order =order_1, hue_order=["Female","Male"],ci=100,saturation=10, errwidth=1)
plt.show()

# %%
#Scatterplot

# %%
x = sns.load_dataset("penguins").head(20)

# %%
sns.scatterplot(x="bill_length_mm",
                y="bill_depth_mm",data = x,hue="sex",sizes=(10,12))
plt.show()

# %%
#Heatmap

# %%
data = sns.load_dataset("anagrams")
x = data.drop(columns=["attnr"],axis=1).head(10)
x

# %%
sns.heatmap(x, vmin=0, vmax=20,cmap="PuOr",annot=True, linewidth=1,linecolor="g")

# %%
#count

# %%
var = sns.load_dataset("tips")
var

# %%
sns.countplot(x="sex", data=var, hue="smoker",color="r")
plt.show()

# %%
#violine plot same as box plot

# %%
x = sns.load_dataset("tips")
x

# %%
sns.violinplot(x="day",y="total_bill",data=x) 
plt.show()

# %%
#pair plot

# %%
x = sns.load_dataset("tips")
x

# %%
sns.pairplot(x)
plt.show()
